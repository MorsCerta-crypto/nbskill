# %% [markdown]
# ## A tiny notebook

# %%
x = 2
x + 3
# Out:
# nbskill.execute._ExecutionApprovalRequired: nbskill: refusing to execute unapproved cell id=5f3584ad. Run it once yourself, or rerun nbskill with allow_new=True if you approve this source.

# %% [markdown]
# ## Result
# The next cell computes from the earlier value.

# %%
answer = x * 12
answer

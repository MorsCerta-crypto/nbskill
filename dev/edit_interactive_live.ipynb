# %% [markdown]
# # Edit Interactive Live Fixture
#
# This notebook demonstrates a corrected triple helper function and its check.

# %%
def triple(x):
    return x * 3

# %%
assert triple(1) == 3
assert triple(2) == 6
print("triple checks passed")
# Out:
# triple checks passed
